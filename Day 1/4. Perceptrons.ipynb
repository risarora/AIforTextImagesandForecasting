# %%
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Artificial Neural Networks

# %% [markdown]
# A neural network consists of a number of neurons connected to each other.

# %% [markdown]
# #	Introducing Perceptrons

# %% [markdown]
# ## The smallest processing unit of a neural network is called a perceptron
# The perceptron consists of 4 parts .
# * **Input values**
# * **Weights and Bias**
# * **Net sum**
# * **Activation Function**
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# ### The perceptron works on these simple steps
# a. All the inputs x are multiplied with their weights w. Let’s call it k.
# ![./images/perceptron2.png](./images/perceptron2.png)
#
#
#
# b. Add all the multiplied values and call them Weighted Sum.
# ![./images/addweights.gif](./images/addweights.gif)
#
#
# c. Apply that weighted sum to the correct Activation Function.
# For Example : Unit Step Activation Function.
#
#
# ![./images/applyactivation.png](./images/applyactivation.png)

# %% [markdown]
# ##	Linear Separability and Xor Problem
# ### XOR
# ![./images/xor.png](./images/xor.png)

# %%
x = np.array([[0, 0], 
              [1, 0], 
              [1, 1], 
              [0, 1]])              # 4x2, input
y = np.array([0, 1, 0, 1])                     # XOR operation
plt.scatter(x[:, 0], x[:, 1], c=y, s=100, cmap='viridis')
#plt.plot(plot_x, plot_y, color='k', linewidth=2)
plt.xlim([-0.2, 1.2]); plt.ylim([-0.2, 1.25]);
plt.show()

# %% [markdown]
# ##	Activation Functions

# %% [markdown]
# ### Stepwise Activation Function
# ![./images/stepwiseActivationFunction.png](./images/stepwiseActivationFunction.png)

# %% [markdown]
# ### Sigmoid Function
# ![./images/sigmoidf.png](./images/sigmoidf.png)
# ![./images/sigmoid.png](./images/sigmoid.png)

# %% [markdown]
# ### Relu Function
# ![./images/reluf.png](./images/reluf.png)
# <img src="./images/relu.png" width="350" height="250">

# %% [markdown]
# ##	Softmax output

# %% [markdown]
# Softmax
# The sigmoid function can be applied easily, the ReLUs will not vanish the effect during your training process. However, when you want to deal with classification problems, they cannot help much. Simply speaking, the sigmoid function can only handle two classes, which is not what we expect.
#
# How does a softmax function work
#
# The softmax function squashes the outputs of each unit to be between 0 and 1, just like a sigmoid function. But it also divides each output such that the total sum of the outputs is equal to 1 (check it on the figure above).
#
# ![./images/softmax.png](./images/softmax.png)
#
# The output of the softmax function is equivalent to a categorical probability distribution, it tells you the probability that any of the classes are true.
#
# Mathematically the softmax function is shown below, where z is a vector of the inputs to the output layer (if you have 10 output units, then there are 10 elements in z). And again, j indexes the output units, so j = 1, 2, ..., K.
#
# The softmax function
#
# ![./images/softmaxFormula.png](./images/softmaxFormula.png)

# %% [markdown]
# ##	Backpropagation, loss functions, and Gradient Descent

# %% [markdown]
# # Loss Function
# ### it’s a method of evaluating how well your algorithm models your dataset.

# %% [markdown]
# ## In Regression Losses,
#
# 1. Mean squared error
# ![./images/MSE.png](./images/MSE.png)
#
# 2. Mean absolute error
# ![./images/MAE.png](./images/MAE.png)
#
# 3. Mean bias error.
# ![./images/MBE.png](./images/MBE.png)
#
#
# ## In Classification Losses,
#
# 1. Hinge or svm  loss
# ![./images/SVMLoss.png](./images/SVMLoss.png)
#
# 2. Cross Entropy loss aka Log Loss
# ![./images/CrossEntropyLoss.png](./images/CrossEntropyLoss.png)

# %% [markdown]
# **What’s the Difference between a Loss Function and a Cost Function ?**
# Although cost function and loss function are synonymous and used interchangeably, they are different.
# A loss function is for a single training example. It is also sometimes called an error function. A cost function, on the other hand, is the average loss over the entire training dataset. The optimization strategies aim at minimizing the cost function.

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# This is an iterative optimization algorithm for finding the minimum of a function. The algorithm takes steps proportional to the negative gradient of the function at the current point.
# In deep learning neural networks are trained by defining a loss function and optimizing the parameters of the network to obtain the minimum of the function. the optimization is dne using the gradient descent algorithm which operates in these two steps:
# * **Compute the slope (gradient) that is first order derivative of the function at the current point**
# * **Move in the opposite direction of the slope increase from the current point by the computed amount**

# %% [markdown]
# ![./images/gradientDecent.png](./images/gradientDecent.png)Gradient Descent [1]

# %% [markdown]
# ### Types of Gradient Descent
#
# * **Stochastic Gradient Descent**
# * **Batch Gradient Descent**
# * **Mini Batch Gradient Descent**

# %% [markdown]
# ### Why do we need Weights and Bias?
#
# Weights shows the strength of the particular node.
# A bias value allows you to shift the activation function curve up or down.

# %% [markdown]
# ### Why do we need Activation Function?
# In short, the activation functions are used to map the input between the required values like (0, 1) or (-1, 1).
# For a better explanation go to my previous story Activation Functions : Neural Networks.
# Where we use Perceptron?
# Perceptron is usually used to classify the data into two parts. Therefore, it is also known as a Linear Binary Classifier.

# %% [markdown]
# [1] https://www.oreilly.com/library/view/learn-arcore-/9781788830409/e24a657a-a5c6-4ff2-b9ea-9418a7a5d24c.xhtml
# [2] https://towardsdatascience.com/what-the-hell-is-perceptron-626217814f53
