# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
from keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer(num_words=100)

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(tokenizer.vocab_size,64))
model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(64)))
model.add(keras.layers.Dense(64,activation=tf.nn.relu))
model.add(keras.layers.Dense(1,activation='sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-b77264effa7f> in <module>
#       1 model = keras.Sequential()
# ----> 2 model.add(keras.layers.Embedding(tokenizer.vocab_size,64))
#       3 model.add(keras.layers.Bidirectional(tf.keras.layers.LSTM(64)))
#       4 model.add(keras.layers.Dense(64,activation=tf.nn.relu))
#       5 model.add(keras.layers.Dense(1,activation='sigmoid'))
#
# AttributeError: 'Tokenizer' object has no attribute 'vocab_size'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](./image/50epochAccuracy.png)

# %% [markdown]
# ![image.png](./image/50epochLoss.png)

# %%
model = tf.keras.Sequential([
tf.keras.layers.Embedding(tokenizer.vocab_size,64)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a2adb1ee5a5c> in <module>
#       1 model = tf.keras.Sequential([
# ----> 2 tf.keras.layers.Embedding(tokenizer.vocab_size,64)])
#
# NameError: name 'tokenizer' is not defined
